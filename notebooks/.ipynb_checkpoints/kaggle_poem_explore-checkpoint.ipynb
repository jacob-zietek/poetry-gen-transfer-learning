# %%
import pandas as pd

# %%
df = pd.read_csv("kaggle_poem_dataset.csv")

# %%
df
# Out:
#        Unnamed: 0                Author  \
# 0               0        Wendy Videlock
# 1               1     Hailey Leithauser
# 2               2         Jody Gladding
# 3               3        Joseph Brodsky
# 4               4          Ted Berrigan
# ...           ...                   ...
# 15647       15647         Hannah Gamble
# 15648       15648      Eleni Sikelianos
# 15649       15649  Susan Elizabeth Howe
# 15650       15650        Andrew Shields
# 15651       15651     Joseph O. Legaspi
#
#                                                    Title  \
# 0                                                      !
# 1                                                      0
# 2                                             1-800-FEAR
# 3                                         1 January 1965
# 4                                                3 Pages
# ...                                                  ...
# 15647              Your Invitation to a Modest Breakfast
# ...

# %%
df[df["Author"].str.contains("William Shakespeare")]
# Out:
#        Unnamed: 0               Author  \
# 10297       10297  William Shakespeare
# 11042       11042  William Shakespeare
# 12369       12369  William Shakespeare
# 12371       12371  William Shakespeare
# 12374       12374  William Shakespeare
# ...           ...                  ...
# 12714       12714  William Shakespeare
# 12715       12715  William Shakespeare
# 12716       12716  William Shakespeare
# 12717       12717  William Shakespeare
# 14512       14512  William Shakespeare
#
#                                                    Title  \
# 10297                         The Phoenix and the Turtle
# 11042                    from\n  \n  The Rape of Lucrece
# 12369  Song: “\n  \n   Blow, blow, thou winter wind\n...
# 12371       Song: “\n  \n   Come away, come away, death”
# 12374  Song: “\n  \n   Fear no more the heat o’ the sun”
# ...                                                  ...
# 12714  Speech: “\n  \n   This day is called the feast...
# ...

# %%
poems_will = df[df["Author"].str.contains("William Shakespeare")]

# %%
poems_will
# Out:
#        Unnamed: 0               Author  \
# 10297       10297  William Shakespeare
# 11042       11042  William Shakespeare
# 12369       12369  William Shakespeare
# 12371       12371  William Shakespeare
# 12374       12374  William Shakespeare
# ...           ...                  ...
# 12714       12714  William Shakespeare
# 12715       12715  William Shakespeare
# 12716       12716  William Shakespeare
# 12717       12717  William Shakespeare
# 14512       14512  William Shakespeare
#
#                                                    Title  \
# 10297                         The Phoenix and the Turtle
# 11042                    from\n  \n  The Rape of Lucrece
# 12369  Song: “\n  \n   Blow, blow, thou winter wind\n...
# 12371       Song: “\n  \n   Come away, come away, death”
# 12374  Song: “\n  \n   Fear no more the heat o’ the sun”
# ...                                                  ...
# 12714  Speech: “\n  \n   This day is called the feast...
# ...

# %%
df["Author"].value_counts()
# Out:
# William Shakespeare      85
# Anonymous                82
# Alfred, Lord Tennyson    78
# Rae Armantrout           62
# William Wordsworth       59
#                          ..
# Judith Hall               1
# Paul Grant                1
# Lois Beebe Hayna          1
# David Kirby               1
# Eleni Sikelianos          1
# Name: Author, Length: 3310, dtype: int64
